# %%
import numpy as np
import Nio

# %%
f = Nio.open_file("../slp.2012.nc")

# %%
print(f)

# %%
globalAtts = f.attributes.keys()

# %%
globalAtts

# %%
varNames = f.variables.keys()

# %%
print(varNames)

# %%
var = f.variables['slp']

# %%
print(var)

# %%
var

# %%
var.shape

# %%
type(var)

# %%
var.attributes

# %%
var.dimensions

# %%
type(f)
